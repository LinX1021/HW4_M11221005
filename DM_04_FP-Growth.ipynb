# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn import datasets
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
from apyori import apriori as asp_apr

# %%
df = pd.read_excel("交易資料集_後處理.xlsx",header = None)
df
# Out:
#                       0                   1                   2    \
# 0      BX80646I54460SR1QK  BX80662I36100SR2HG  BX80662I56400SR2L7
# 1           PBSS4350T,215       PMBT2222A,215                 NaN
# 2              BAT54A,215          BAT54C,215           BAV99,215
# 3              BAT54A,215          BAT54C,215        NX7002AK,215
# 4         74AHC1G08GV,125        74HC125D,653      74LVC125AD,118
# ...                   ...                 ...                 ...
# 36493             LM193DR                 NaN                 NaN
# 36494      1SS357(TPH3,F)                 NaN                 NaN
# 36495      1SS357(TPH3,F)                 NaN                 NaN
# 36496     JS28F512M29EWHA                 NaN                 NaN
# 36497    T6TD3XB-0003(LO)                 NaN                 NaN
#
#                       3                   4                5    \
# 0      BX80662I56500SR2L6  BX80662I76700SR2L2   X79A-GD45-PLUS
# ...

# %%
transaction = []
for i in range(0,36498):
    transaction.append([str(df.values[i,j]) for j in range(0,251)])

# %%
te = TransactionEncoder()
te_array = te.fit(transaction).transform(transaction)
te_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df = pd.DataFrame(te_array, columns = te.columns_)
df = df.drop(labels=['nan'],axis=1)
df
# Out:
#        01000054Z  01000056Z  01000057Z  01220088Z  01220090Z  01250003H  \
# 0          False      False      False      False      False      False
# 1          False      False      False      False      False      False
# 2          False      False      False      False      False      False
# 3          False      False      False      False      False      False
# 4          False      False      False      False      False      False
# ...          ...        ...        ...        ...        ...        ...
# 36493      False      False      False      False      False      False
# 36494      False      False      False      False      False      False
# 36495      False      False      False      False      False      False
# 36496      False      False      False      False      False      False
# 36497      False      False      False      False      False      False
#
#        01500274Z  01500322H  01520903TXN  0154004.DR  ...  ZLUSBEVAL3Z  \
# ...

# %%
start_fp = time.time()
res = fpgrowth(df, min_support = 0.0015, use_colnames = True)
out = association_rules(res, metric = "confidence", min_threshold = 0.7)
end_fp = time.time()
print("FP-Growth 花費時間:", end_fp - start_fp)
out
# Out:
# FP-Growth 花費時間: 2.2504429817199707
#   antecedents consequents  antecedent support  consequent support   support  \
# 0  (SC6531DA)   (HS8292U)            0.001562            0.001781  0.001562
# 1   (HS8292U)  (SC6531DA)            0.001781            0.001562  0.001562
#
#    confidence        lift  leverage  conviction  zhangs_metric
# 0    1.000000  561.507692  0.001559         inf        0.99978
# 1    0.876923  561.507692  0.001559    8.112311        1.00000

# %%
start_fp = time.time()
res = fpgrowth(df, min_support = 0.00125, use_colnames = True)
out = association_rules(res, metric = "confidence", min_threshold = 0.7)
end_fp = time.time()
print("FP-Growth 花費時間:", end_fp - start_fp)
out
# Out:
# FP-Growth 花費時間: 1.151820182800293
#                antecedents      consequents  antecedent support  \
# 0             (PDZ15B,115)     (BAS316,115)            0.001671
# 1  (BAS316,115, BAV70,215)      (BAV99,215)            0.001480
# 2          (PBSS4240T,215)  (PBSS5240T,215)            0.001397
# 3               (SC6531DA)        (HS8292U)            0.001562
# 4                (HS8292U)       (SC6531DA)            0.001781
#
#    consequent support   support  confidence        lift  leverage  conviction  \
# 0            0.004576  0.001260    0.754098  164.808874  0.001253    4.048059
# 1            0.008137  0.001315    0.888889  109.234568  0.001303    8.926763
# 2            0.001891  0.001260    0.901961  477.098039  0.001258   10.180717
# 3            0.001781  0.001562    1.000000  561.507692  0.001559         inf
# 4            0.001562  0.001562    0.876923  561.507692  0.001559    8.112311
#
#    zhangs_metric
# 0       0.995596
# 1       0.992314
# 2       0.999300
# ...

# %%
start_fp = time.time()
res = fpgrowth(df, min_support = 0.001, use_colnames = True)
out = association_rules(res, metric = "confidence", min_threshold = 0.7)
end_fp = time.time()
print("FP-Growth 花費時間:", end_fp - start_fp)
out
# Out:
# FP-Growth 花費時間: 1.182905912399292
#                    antecedents      consequents  antecedent support  \
# 0     (BAT54C,215, BAT54A,215)      (BAV99,215)            0.001425
# 1                 (PDZ12B,115)     (BAS316,115)            0.001507
# 2       (BAV99,215, BAW56,215)     (BAS316,115)            0.001562
# 3      (BAW56,215, BAS316,115)      (BAV99,215)            0.001315
# 4                 (PDZ15B,115)     (BAS316,115)            0.001671
# 5                 (PDZ15B,115)      (BAV99,215)            0.001671
# 6      (BAV99,215, PDZ15B,115)     (BAS316,115)            0.001233
# 7     (BAS316,115, PDZ15B,115)      (BAV99,215)            0.001260
# 8    (BAV99,215, 2N7002BK,215)     (BAS316,115)            0.001233
# 9   (2N7002BK,215, BAS316,115)      (BAV99,215)            0.001151
# 10     (BAS316,115, BAV70,215)      (BAV99,215)            0.001480
# 11     (BAT54S,215, BAV70,215)      (BAV99,215)            0.001178
# ...
